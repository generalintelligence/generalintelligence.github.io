# %%
from IPython.display import HTML

HTML('''<script>
  function code_toggle() {
    if (code_shown){
      $('div.input').hide('500');
      $('#toggleButton').val('Show Code')
    } else {
      $('div.input').show('500');
      $('#toggleButton').val('Hide Code')
    }
    code_shown = !code_shown
  }

  $( document ).ready(function(){
    code_shown=false;
    $('div.input').hide()
  });
</script>
<form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>''')
# Out:
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>

# %%
# %matplotlib inline
from IPython.display import Image
Image("img/sam.png", width=100, height=150)

# %% [markdown]
# ## **Sam Farley, BS Chem, Senior Consultant**:
#
# Samuel J. Farley graduated from Carnegie Mellon University in 2016 with a BS in Chemistry. While at CMU, Sam worked as an undergraduate research assistant under Dr Terrence J. Collins, and founded CCCACS, the CMU Cannabis Chemistry, Agriculture, and Commerce Society, to serve as a focal point for members of the community interested in any aspect of the growing cannabis field.

# %%
Image("img/jason.jpg", width=125, height=150)

# %% [markdown]
# ## **Jason Larkin, PhD, Senior Consultant**
#
# Jason got his PhD at CMU in 2013 in the field of Modeling/Simulation and High Performance Computing.
#
# Jason's research interests include:
#
# * Modern Grow Techniques
# * Nutrition/Fitness
#
# <!---
# //* AI/Machine Learning/Natural Language Processing
# //* High Performance/Cloud Computing
# //* Human Computer Interaction
#
# //* Performance Motorsports
# -->
#
# [http://jasonlarkin.org/](http://jasonlarkin.org/)
